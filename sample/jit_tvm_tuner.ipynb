# %%
import torch
import torch.nn as nn
from brt.jit.tvm import TVMTuner

class Expert1(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.linear = nn.Linear(512, 1024)

    def forward(self, inputs):
        return self.linear(inputs)


tvm_tuner = TVMTuner()
tvm_tuner.import_pt_netlet(
    "Linear",
    Expert1(),
    input_infos={"input0": (1, 512)},
    output_infos={"output0": (1, 1024)},
    parameters={"weight": (512, 1024), "bias": (1, 1024)},
    log_fname="Linear_1_512_1024.json",
)

gird_size, block_size, source_code = tvm_tuner.get_best_template()
# Out:
# Get devices for measurement successfully!

# %%
tvm_tuner.inject_netlet_to_storage()
# Out:
# {'input_shape:': [(1, 512)], 'output_shape:': [(1, 1024)], 'parameters:': [(512, 1024), (1, 1024)]}
#
# #define uint unsigned int
# #define uchar unsigned char
# #define ushort unsigned short
# #define int64_t long long
# #define uint64_t unsigned long long
# extern "C" __global__ void __launch_bounds__(8) default_function_kernel0(float* __restrict__ placeholder, float* __restrict__ placeholder1, float* __restrict__ T_add, float* __restrict__ placeholder2) {
#   // [kernel_type] global
#   // [thread_extent] blockIdx.x = 128
#   // [thread_extent] blockIdx.y = 1
#   // [thread_extent] blockIdx.z = 1
#   // [thread_extent] threadIdx.x = 8
#   // [thread_extent] threadIdx.y = 1
#   // [thread_extent] threadIdx.z = 1
#
#   __shared__ float placeholder_d_shared[512];
#   __shared__ float placeholder_shared[4096];
#
#   float T_matmul_NT[1];
#   T_matmul_NT[0] = 0.000000e+00f;
#   *(float2*)(placeholder_d_shared + (((int)threadIdx.x) * 2)) = *(float2*)(placeholder + (((int)threadIdx.x) * 2));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 16)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 16));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 32)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 32));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 48)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 48));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 64)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 64));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 80)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 80));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 96)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 96));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 112)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 112));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 128)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 128));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 144)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 144));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 160)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 160));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 176)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 176));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 192)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 192));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 208)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 208));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 224)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 224));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 240)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 240));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 256)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 256));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 272)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 272));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 288)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 288));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 304)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 304));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 320)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 320));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 336)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 336));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 352)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 352));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 368)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 368));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 384)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 384));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 400)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 400));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 416)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 416));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 432)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 432));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 448)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 448));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 464)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 464));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 480)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 480));
#   *(float2*)(placeholder_d_shared + ((((int)threadIdx.x) * 2) + 496)) = *(float2*)(placeholder + ((((int)threadIdx.x) * 2) + 496));
#   *(float4*)(placeholder_shared + (((int)threadIdx.x) * 4)) = *(float4*)(placeholder1 + ((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 32)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 32));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 64)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 64));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 96)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 96));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 128)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 128));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 160)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 160));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 192)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 192));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 224)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 224));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 256)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 256));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 288)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 288));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 320)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 320));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 352)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 352));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 384)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 384));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 416)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 416));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 448)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 448));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 480)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 480));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 512)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 512));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 544)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 544));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 576)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 576));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 608)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 608));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 640)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 640));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 672)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 672));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 704)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 704));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 736)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 736));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 768)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 768));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 800)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 800));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 832)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 832));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 864)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 864));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 896)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 896));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 928)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 928));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 960)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 960));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 992)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 992));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1024)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1024));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1056)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1056));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1088)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1088));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1120)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1120));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1152)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1152));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1184)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1184));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1216)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1216));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1248)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1248));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1280)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1280));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1312)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1312));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1344)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1344));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1376)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1376));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1408)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1408));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1440)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1440));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1472)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1472));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1504)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1504));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1536)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1536));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1568)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1568));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1600)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1600));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1632)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1632));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1664)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1664));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1696)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1696));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1728)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1728));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1760)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1760));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1792)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1792));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1824)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1824));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1856)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1856));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1888)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1888));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1920)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1920));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1952)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1952));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 1984)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 1984));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2016)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2016));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2048)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2048));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2080)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2080));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2112)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2112));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2144)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2144));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2176)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2176));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2208)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2208));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2240)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2240));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2272)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2272));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2304)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2304));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2336)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2336));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2368)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2368));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2400)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2400));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2432)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2432));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2464)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2464));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2496)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2496));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2528)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2528));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2560)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2560));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2592)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2592));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2624)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2624));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2656)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2656));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2688)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2688));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2720)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2720));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2752)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2752));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2784)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2784));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2816)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2816));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2848)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2848));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2880)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2880));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2912)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2912));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2944)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2944));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 2976)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 2976));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3008)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3008));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3040)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3040));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3072)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3072));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3104)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3104));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3136)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3136));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3168)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3168));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3200)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3200));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3232)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3232));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3264)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3264));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3296)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3296));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3328)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3328));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3360)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3360));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3392)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3392));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3424)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3424));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3456)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3456));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3488)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3488));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3520)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3520));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3552)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3552));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3584)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3584));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3616)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3616));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3648)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3648));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3680)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3680));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3712)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3712));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3744)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3744));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3776)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3776));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3808)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3808));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3840)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3840));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3872)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3872));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3904)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3904));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3936)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3936));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 3968)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 3968));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 4000)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 4000));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 4032)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 4032));
#   *(float4*)(placeholder_shared + ((((int)threadIdx.x) * 4) + 4064)) = *(float4*)(placeholder1 + (((((int)blockIdx.x) * 4096) + (((int)threadIdx.x) * 4)) + 4064));
#   __syncthreads();
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[0] * placeholder_shared[(((int)threadIdx.x) * 512)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[1] * placeholder_shared[((((int)threadIdx.x) * 512) + 1)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[2] * placeholder_shared[((((int)threadIdx.x) * 512) + 2)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[3] * placeholder_shared[((((int)threadIdx.x) * 512) + 3)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[4] * placeholder_shared[((((int)threadIdx.x) * 512) + 4)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[5] * placeholder_shared[((((int)threadIdx.x) * 512) + 5)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[6] * placeholder_shared[((((int)threadIdx.x) * 512) + 6)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[7] * placeholder_shared[((((int)threadIdx.x) * 512) + 7)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[8] * placeholder_shared[((((int)threadIdx.x) * 512) + 8)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[9] * placeholder_shared[((((int)threadIdx.x) * 512) + 9)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[10] * placeholder_shared[((((int)threadIdx.x) * 512) + 10)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[11] * placeholder_shared[((((int)threadIdx.x) * 512) + 11)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[12] * placeholder_shared[((((int)threadIdx.x) * 512) + 12)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[13] * placeholder_shared[((((int)threadIdx.x) * 512) + 13)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[14] * placeholder_shared[((((int)threadIdx.x) * 512) + 14)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[15] * placeholder_shared[((((int)threadIdx.x) * 512) + 15)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[16] * placeholder_shared[((((int)threadIdx.x) * 512) + 16)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[17] * placeholder_shared[((((int)threadIdx.x) * 512) + 17)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[18] * placeholder_shared[((((int)threadIdx.x) * 512) + 18)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[19] * placeholder_shared[((((int)threadIdx.x) * 512) + 19)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[20] * placeholder_shared[((((int)threadIdx.x) * 512) + 20)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[21] * placeholder_shared[((((int)threadIdx.x) * 512) + 21)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[22] * placeholder_shared[((((int)threadIdx.x) * 512) + 22)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[23] * placeholder_shared[((((int)threadIdx.x) * 512) + 23)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[24] * placeholder_shared[((((int)threadIdx.x) * 512) + 24)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[25] * placeholder_shared[((((int)threadIdx.x) * 512) + 25)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[26] * placeholder_shared[((((int)threadIdx.x) * 512) + 26)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[27] * placeholder_shared[((((int)threadIdx.x) * 512) + 27)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[28] * placeholder_shared[((((int)threadIdx.x) * 512) + 28)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[29] * placeholder_shared[((((int)threadIdx.x) * 512) + 29)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[30] * placeholder_shared[((((int)threadIdx.x) * 512) + 30)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[31] * placeholder_shared[((((int)threadIdx.x) * 512) + 31)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[32] * placeholder_shared[((((int)threadIdx.x) * 512) + 32)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[33] * placeholder_shared[((((int)threadIdx.x) * 512) + 33)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[34] * placeholder_shared[((((int)threadIdx.x) * 512) + 34)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[35] * placeholder_shared[((((int)threadIdx.x) * 512) + 35)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[36] * placeholder_shared[((((int)threadIdx.x) * 512) + 36)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[37] * placeholder_shared[((((int)threadIdx.x) * 512) + 37)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[38] * placeholder_shared[((((int)threadIdx.x) * 512) + 38)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[39] * placeholder_shared[((((int)threadIdx.x) * 512) + 39)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[40] * placeholder_shared[((((int)threadIdx.x) * 512) + 40)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[41] * placeholder_shared[((((int)threadIdx.x) * 512) + 41)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[42] * placeholder_shared[((((int)threadIdx.x) * 512) + 42)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[43] * placeholder_shared[((((int)threadIdx.x) * 512) + 43)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[44] * placeholder_shared[((((int)threadIdx.x) * 512) + 44)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[45] * placeholder_shared[((((int)threadIdx.x) * 512) + 45)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[46] * placeholder_shared[((((int)threadIdx.x) * 512) + 46)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[47] * placeholder_shared[((((int)threadIdx.x) * 512) + 47)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[48] * placeholder_shared[((((int)threadIdx.x) * 512) + 48)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[49] * placeholder_shared[((((int)threadIdx.x) * 512) + 49)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[50] * placeholder_shared[((((int)threadIdx.x) * 512) + 50)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[51] * placeholder_shared[((((int)threadIdx.x) * 512) + 51)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[52] * placeholder_shared[((((int)threadIdx.x) * 512) + 52)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[53] * placeholder_shared[((((int)threadIdx.x) * 512) + 53)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[54] * placeholder_shared[((((int)threadIdx.x) * 512) + 54)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[55] * placeholder_shared[((((int)threadIdx.x) * 512) + 55)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[56] * placeholder_shared[((((int)threadIdx.x) * 512) + 56)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[57] * placeholder_shared[((((int)threadIdx.x) * 512) + 57)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[58] * placeholder_shared[((((int)threadIdx.x) * 512) + 58)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[59] * placeholder_shared[((((int)threadIdx.x) * 512) + 59)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[60] * placeholder_shared[((((int)threadIdx.x) * 512) + 60)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[61] * placeholder_shared[((((int)threadIdx.x) * 512) + 61)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[62] * placeholder_shared[((((int)threadIdx.x) * 512) + 62)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[63] * placeholder_shared[((((int)threadIdx.x) * 512) + 63)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[64] * placeholder_shared[((((int)threadIdx.x) * 512) + 64)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[65] * placeholder_shared[((((int)threadIdx.x) * 512) + 65)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[66] * placeholder_shared[((((int)threadIdx.x) * 512) + 66)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[67] * placeholder_shared[((((int)threadIdx.x) * 512) + 67)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[68] * placeholder_shared[((((int)threadIdx.x) * 512) + 68)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[69] * placeholder_shared[((((int)threadIdx.x) * 512) + 69)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[70] * placeholder_shared[((((int)threadIdx.x) * 512) + 70)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[71] * placeholder_shared[((((int)threadIdx.x) * 512) + 71)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[72] * placeholder_shared[((((int)threadIdx.x) * 512) + 72)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[73] * placeholder_shared[((((int)threadIdx.x) * 512) + 73)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[74] * placeholder_shared[((((int)threadIdx.x) * 512) + 74)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[75] * placeholder_shared[((((int)threadIdx.x) * 512) + 75)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[76] * placeholder_shared[((((int)threadIdx.x) * 512) + 76)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[77] * placeholder_shared[((((int)threadIdx.x) * 512) + 77)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[78] * placeholder_shared[((((int)threadIdx.x) * 512) + 78)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[79] * placeholder_shared[((((int)threadIdx.x) * 512) + 79)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[80] * placeholder_shared[((((int)threadIdx.x) * 512) + 80)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[81] * placeholder_shared[((((int)threadIdx.x) * 512) + 81)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[82] * placeholder_shared[((((int)threadIdx.x) * 512) + 82)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[83] * placeholder_shared[((((int)threadIdx.x) * 512) + 83)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[84] * placeholder_shared[((((int)threadIdx.x) * 512) + 84)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[85] * placeholder_shared[((((int)threadIdx.x) * 512) + 85)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[86] * placeholder_shared[((((int)threadIdx.x) * 512) + 86)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[87] * placeholder_shared[((((int)threadIdx.x) * 512) + 87)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[88] * placeholder_shared[((((int)threadIdx.x) * 512) + 88)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[89] * placeholder_shared[((((int)threadIdx.x) * 512) + 89)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[90] * placeholder_shared[((((int)threadIdx.x) * 512) + 90)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[91] * placeholder_shared[((((int)threadIdx.x) * 512) + 91)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[92] * placeholder_shared[((((int)threadIdx.x) * 512) + 92)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[93] * placeholder_shared[((((int)threadIdx.x) * 512) + 93)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[94] * placeholder_shared[((((int)threadIdx.x) * 512) + 94)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[95] * placeholder_shared[((((int)threadIdx.x) * 512) + 95)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[96] * placeholder_shared[((((int)threadIdx.x) * 512) + 96)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[97] * placeholder_shared[((((int)threadIdx.x) * 512) + 97)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[98] * placeholder_shared[((((int)threadIdx.x) * 512) + 98)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[99] * placeholder_shared[((((int)threadIdx.x) * 512) + 99)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[100] * placeholder_shared[((((int)threadIdx.x) * 512) + 100)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[101] * placeholder_shared[((((int)threadIdx.x) * 512) + 101)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[102] * placeholder_shared[((((int)threadIdx.x) * 512) + 102)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[103] * placeholder_shared[((((int)threadIdx.x) * 512) + 103)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[104] * placeholder_shared[((((int)threadIdx.x) * 512) + 104)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[105] * placeholder_shared[((((int)threadIdx.x) * 512) + 105)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[106] * placeholder_shared[((((int)threadIdx.x) * 512) + 106)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[107] * placeholder_shared[((((int)threadIdx.x) * 512) + 107)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[108] * placeholder_shared[((((int)threadIdx.x) * 512) + 108)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[109] * placeholder_shared[((((int)threadIdx.x) * 512) + 109)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[110] * placeholder_shared[((((int)threadIdx.x) * 512) + 110)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[111] * placeholder_shared[((((int)threadIdx.x) * 512) + 111)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[112] * placeholder_shared[((((int)threadIdx.x) * 512) + 112)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[113] * placeholder_shared[((((int)threadIdx.x) * 512) + 113)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[114] * placeholder_shared[((((int)threadIdx.x) * 512) + 114)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[115] * placeholder_shared[((((int)threadIdx.x) * 512) + 115)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[116] * placeholder_shared[((((int)threadIdx.x) * 512) + 116)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[117] * placeholder_shared[((((int)threadIdx.x) * 512) + 117)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[118] * placeholder_shared[((((int)threadIdx.x) * 512) + 118)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[119] * placeholder_shared[((((int)threadIdx.x) * 512) + 119)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[120] * placeholder_shared[((((int)threadIdx.x) * 512) + 120)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[121] * placeholder_shared[((((int)threadIdx.x) * 512) + 121)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[122] * placeholder_shared[((((int)threadIdx.x) * 512) + 122)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[123] * placeholder_shared[((((int)threadIdx.x) * 512) + 123)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[124] * placeholder_shared[((((int)threadIdx.x) * 512) + 124)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[125] * placeholder_shared[((((int)threadIdx.x) * 512) + 125)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[126] * placeholder_shared[((((int)threadIdx.x) * 512) + 126)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[127] * placeholder_shared[((((int)threadIdx.x) * 512) + 127)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[128] * placeholder_shared[((((int)threadIdx.x) * 512) + 128)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[129] * placeholder_shared[((((int)threadIdx.x) * 512) + 129)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[130] * placeholder_shared[((((int)threadIdx.x) * 512) + 130)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[131] * placeholder_shared[((((int)threadIdx.x) * 512) + 131)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[132] * placeholder_shared[((((int)threadIdx.x) * 512) + 132)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[133] * placeholder_shared[((((int)threadIdx.x) * 512) + 133)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[134] * placeholder_shared[((((int)threadIdx.x) * 512) + 134)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[135] * placeholder_shared[((((int)threadIdx.x) * 512) + 135)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[136] * placeholder_shared[((((int)threadIdx.x) * 512) + 136)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[137] * placeholder_shared[((((int)threadIdx.x) * 512) + 137)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[138] * placeholder_shared[((((int)threadIdx.x) * 512) + 138)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[139] * placeholder_shared[((((int)threadIdx.x) * 512) + 139)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[140] * placeholder_shared[((((int)threadIdx.x) * 512) + 140)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[141] * placeholder_shared[((((int)threadIdx.x) * 512) + 141)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[142] * placeholder_shared[((((int)threadIdx.x) * 512) + 142)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[143] * placeholder_shared[((((int)threadIdx.x) * 512) + 143)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[144] * placeholder_shared[((((int)threadIdx.x) * 512) + 144)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[145] * placeholder_shared[((((int)threadIdx.x) * 512) + 145)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[146] * placeholder_shared[((((int)threadIdx.x) * 512) + 146)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[147] * placeholder_shared[((((int)threadIdx.x) * 512) + 147)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[148] * placeholder_shared[((((int)threadIdx.x) * 512) + 148)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[149] * placeholder_shared[((((int)threadIdx.x) * 512) + 149)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[150] * placeholder_shared[((((int)threadIdx.x) * 512) + 150)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[151] * placeholder_shared[((((int)threadIdx.x) * 512) + 151)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[152] * placeholder_shared[((((int)threadIdx.x) * 512) + 152)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[153] * placeholder_shared[((((int)threadIdx.x) * 512) + 153)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[154] * placeholder_shared[((((int)threadIdx.x) * 512) + 154)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[155] * placeholder_shared[((((int)threadIdx.x) * 512) + 155)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[156] * placeholder_shared[((((int)threadIdx.x) * 512) + 156)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[157] * placeholder_shared[((((int)threadIdx.x) * 512) + 157)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[158] * placeholder_shared[((((int)threadIdx.x) * 512) + 158)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[159] * placeholder_shared[((((int)threadIdx.x) * 512) + 159)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[160] * placeholder_shared[((((int)threadIdx.x) * 512) + 160)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[161] * placeholder_shared[((((int)threadIdx.x) * 512) + 161)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[162] * placeholder_shared[((((int)threadIdx.x) * 512) + 162)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[163] * placeholder_shared[((((int)threadIdx.x) * 512) + 163)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[164] * placeholder_shared[((((int)threadIdx.x) * 512) + 164)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[165] * placeholder_shared[((((int)threadIdx.x) * 512) + 165)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[166] * placeholder_shared[((((int)threadIdx.x) * 512) + 166)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[167] * placeholder_shared[((((int)threadIdx.x) * 512) + 167)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[168] * placeholder_shared[((((int)threadIdx.x) * 512) + 168)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[169] * placeholder_shared[((((int)threadIdx.x) * 512) + 169)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[170] * placeholder_shared[((((int)threadIdx.x) * 512) + 170)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[171] * placeholder_shared[((((int)threadIdx.x) * 512) + 171)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[172] * placeholder_shared[((((int)threadIdx.x) * 512) + 172)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[173] * placeholder_shared[((((int)threadIdx.x) * 512) + 173)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[174] * placeholder_shared[((((int)threadIdx.x) * 512) + 174)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[175] * placeholder_shared[((((int)threadIdx.x) * 512) + 175)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[176] * placeholder_shared[((((int)threadIdx.x) * 512) + 176)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[177] * placeholder_shared[((((int)threadIdx.x) * 512) + 177)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[178] * placeholder_shared[((((int)threadIdx.x) * 512) + 178)]));
# ...
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[385] * placeholder_shared[((((int)threadIdx.x) * 512) + 385)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[386] * placeholder_shared[((((int)threadIdx.x) * 512) + 386)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[387] * placeholder_shared[((((int)threadIdx.x) * 512) + 387)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[388] * placeholder_shared[((((int)threadIdx.x) * 512) + 388)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[389] * placeholder_shared[((((int)threadIdx.x) * 512) + 389)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[390] * placeholder_shared[((((int)threadIdx.x) * 512) + 390)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[391] * placeholder_shared[((((int)threadIdx.x) * 512) + 391)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[392] * placeholder_shared[((((int)threadIdx.x) * 512) + 392)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[393] * placeholder_shared[((((int)threadIdx.x) * 512) + 393)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[394] * placeholder_shared[((((int)threadIdx.x) * 512) + 394)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[395] * placeholder_shared[((((int)threadIdx.x) * 512) + 395)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[396] * placeholder_shared[((((int)threadIdx.x) * 512) + 396)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[397] * placeholder_shared[((((int)threadIdx.x) * 512) + 397)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[398] * placeholder_shared[((((int)threadIdx.x) * 512) + 398)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[399] * placeholder_shared[((((int)threadIdx.x) * 512) + 399)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[400] * placeholder_shared[((((int)threadIdx.x) * 512) + 400)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[401] * placeholder_shared[((((int)threadIdx.x) * 512) + 401)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[402] * placeholder_shared[((((int)threadIdx.x) * 512) + 402)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[403] * placeholder_shared[((((int)threadIdx.x) * 512) + 403)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[404] * placeholder_shared[((((int)threadIdx.x) * 512) + 404)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[405] * placeholder_shared[((((int)threadIdx.x) * 512) + 405)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[406] * placeholder_shared[((((int)threadIdx.x) * 512) + 406)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[407] * placeholder_shared[((((int)threadIdx.x) * 512) + 407)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[408] * placeholder_shared[((((int)threadIdx.x) * 512) + 408)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[409] * placeholder_shared[((((int)threadIdx.x) * 512) + 409)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[410] * placeholder_shared[((((int)threadIdx.x) * 512) + 410)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[411] * placeholder_shared[((((int)threadIdx.x) * 512) + 411)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[412] * placeholder_shared[((((int)threadIdx.x) * 512) + 412)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[413] * placeholder_shared[((((int)threadIdx.x) * 512) + 413)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[414] * placeholder_shared[((((int)threadIdx.x) * 512) + 414)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[415] * placeholder_shared[((((int)threadIdx.x) * 512) + 415)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[416] * placeholder_shared[((((int)threadIdx.x) * 512) + 416)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[417] * placeholder_shared[((((int)threadIdx.x) * 512) + 417)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[418] * placeholder_shared[((((int)threadIdx.x) * 512) + 418)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[419] * placeholder_shared[((((int)threadIdx.x) * 512) + 419)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[420] * placeholder_shared[((((int)threadIdx.x) * 512) + 420)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[421] * placeholder_shared[((((int)threadIdx.x) * 512) + 421)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[422] * placeholder_shared[((((int)threadIdx.x) * 512) + 422)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[423] * placeholder_shared[((((int)threadIdx.x) * 512) + 423)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[424] * placeholder_shared[((((int)threadIdx.x) * 512) + 424)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[425] * placeholder_shared[((((int)threadIdx.x) * 512) + 425)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[426] * placeholder_shared[((((int)threadIdx.x) * 512) + 426)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[427] * placeholder_shared[((((int)threadIdx.x) * 512) + 427)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[428] * placeholder_shared[((((int)threadIdx.x) * 512) + 428)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[429] * placeholder_shared[((((int)threadIdx.x) * 512) + 429)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[430] * placeholder_shared[((((int)threadIdx.x) * 512) + 430)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[431] * placeholder_shared[((((int)threadIdx.x) * 512) + 431)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[432] * placeholder_shared[((((int)threadIdx.x) * 512) + 432)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[433] * placeholder_shared[((((int)threadIdx.x) * 512) + 433)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[434] * placeholder_shared[((((int)threadIdx.x) * 512) + 434)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[435] * placeholder_shared[((((int)threadIdx.x) * 512) + 435)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[436] * placeholder_shared[((((int)threadIdx.x) * 512) + 436)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[437] * placeholder_shared[((((int)threadIdx.x) * 512) + 437)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[438] * placeholder_shared[((((int)threadIdx.x) * 512) + 438)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[439] * placeholder_shared[((((int)threadIdx.x) * 512) + 439)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[440] * placeholder_shared[((((int)threadIdx.x) * 512) + 440)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[441] * placeholder_shared[((((int)threadIdx.x) * 512) + 441)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[442] * placeholder_shared[((((int)threadIdx.x) * 512) + 442)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[443] * placeholder_shared[((((int)threadIdx.x) * 512) + 443)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[444] * placeholder_shared[((((int)threadIdx.x) * 512) + 444)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[445] * placeholder_shared[((((int)threadIdx.x) * 512) + 445)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[446] * placeholder_shared[((((int)threadIdx.x) * 512) + 446)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[447] * placeholder_shared[((((int)threadIdx.x) * 512) + 447)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[448] * placeholder_shared[((((int)threadIdx.x) * 512) + 448)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[449] * placeholder_shared[((((int)threadIdx.x) * 512) + 449)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[450] * placeholder_shared[((((int)threadIdx.x) * 512) + 450)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[451] * placeholder_shared[((((int)threadIdx.x) * 512) + 451)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[452] * placeholder_shared[((((int)threadIdx.x) * 512) + 452)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[453] * placeholder_shared[((((int)threadIdx.x) * 512) + 453)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[454] * placeholder_shared[((((int)threadIdx.x) * 512) + 454)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[455] * placeholder_shared[((((int)threadIdx.x) * 512) + 455)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[456] * placeholder_shared[((((int)threadIdx.x) * 512) + 456)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[457] * placeholder_shared[((((int)threadIdx.x) * 512) + 457)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[458] * placeholder_shared[((((int)threadIdx.x) * 512) + 458)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[459] * placeholder_shared[((((int)threadIdx.x) * 512) + 459)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[460] * placeholder_shared[((((int)threadIdx.x) * 512) + 460)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[461] * placeholder_shared[((((int)threadIdx.x) * 512) + 461)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[462] * placeholder_shared[((((int)threadIdx.x) * 512) + 462)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[463] * placeholder_shared[((((int)threadIdx.x) * 512) + 463)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[464] * placeholder_shared[((((int)threadIdx.x) * 512) + 464)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[465] * placeholder_shared[((((int)threadIdx.x) * 512) + 465)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[466] * placeholder_shared[((((int)threadIdx.x) * 512) + 466)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[467] * placeholder_shared[((((int)threadIdx.x) * 512) + 467)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[468] * placeholder_shared[((((int)threadIdx.x) * 512) + 468)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[469] * placeholder_shared[((((int)threadIdx.x) * 512) + 469)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[470] * placeholder_shared[((((int)threadIdx.x) * 512) + 470)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[471] * placeholder_shared[((((int)threadIdx.x) * 512) + 471)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[472] * placeholder_shared[((((int)threadIdx.x) * 512) + 472)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[473] * placeholder_shared[((((int)threadIdx.x) * 512) + 473)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[474] * placeholder_shared[((((int)threadIdx.x) * 512) + 474)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[475] * placeholder_shared[((((int)threadIdx.x) * 512) + 475)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[476] * placeholder_shared[((((int)threadIdx.x) * 512) + 476)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[477] * placeholder_shared[((((int)threadIdx.x) * 512) + 477)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[478] * placeholder_shared[((((int)threadIdx.x) * 512) + 478)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[479] * placeholder_shared[((((int)threadIdx.x) * 512) + 479)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[480] * placeholder_shared[((((int)threadIdx.x) * 512) + 480)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[481] * placeholder_shared[((((int)threadIdx.x) * 512) + 481)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[482] * placeholder_shared[((((int)threadIdx.x) * 512) + 482)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[483] * placeholder_shared[((((int)threadIdx.x) * 512) + 483)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[484] * placeholder_shared[((((int)threadIdx.x) * 512) + 484)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[485] * placeholder_shared[((((int)threadIdx.x) * 512) + 485)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[486] * placeholder_shared[((((int)threadIdx.x) * 512) + 486)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[487] * placeholder_shared[((((int)threadIdx.x) * 512) + 487)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[488] * placeholder_shared[((((int)threadIdx.x) * 512) + 488)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[489] * placeholder_shared[((((int)threadIdx.x) * 512) + 489)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[490] * placeholder_shared[((((int)threadIdx.x) * 512) + 490)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[491] * placeholder_shared[((((int)threadIdx.x) * 512) + 491)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[492] * placeholder_shared[((((int)threadIdx.x) * 512) + 492)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[493] * placeholder_shared[((((int)threadIdx.x) * 512) + 493)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[494] * placeholder_shared[((((int)threadIdx.x) * 512) + 494)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[495] * placeholder_shared[((((int)threadIdx.x) * 512) + 495)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[496] * placeholder_shared[((((int)threadIdx.x) * 512) + 496)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[497] * placeholder_shared[((((int)threadIdx.x) * 512) + 497)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[498] * placeholder_shared[((((int)threadIdx.x) * 512) + 498)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[499] * placeholder_shared[((((int)threadIdx.x) * 512) + 499)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[500] * placeholder_shared[((((int)threadIdx.x) * 512) + 500)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[501] * placeholder_shared[((((int)threadIdx.x) * 512) + 501)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[502] * placeholder_shared[((((int)threadIdx.x) * 512) + 502)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[503] * placeholder_shared[((((int)threadIdx.x) * 512) + 503)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[504] * placeholder_shared[((((int)threadIdx.x) * 512) + 504)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[505] * placeholder_shared[((((int)threadIdx.x) * 512) + 505)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[506] * placeholder_shared[((((int)threadIdx.x) * 512) + 506)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[507] * placeholder_shared[((((int)threadIdx.x) * 512) + 507)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[508] * placeholder_shared[((((int)threadIdx.x) * 512) + 508)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[509] * placeholder_shared[((((int)threadIdx.x) * 512) + 509)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[510] * placeholder_shared[((((int)threadIdx.x) * 512) + 510)]));
#   T_matmul_NT[0] = (T_matmul_NT[0] + (placeholder_d_shared[511] * placeholder_shared[((((int)threadIdx.x) * 512) + 511)]));
#   T_add[((((int)blockIdx.x) * 8) + ((int)threadIdx.x))] = (T_matmul_NT[0] + placeholder2[((((int)blockIdx.x) * 8) + ((int)threadIdx.x))]);
# }
